# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### READ DATASET

# %%
df = pd.read_csv('autos_mpg.csv')

# %% [markdown]
# ### CHECKING AND GETTING A FEEL OF THE DATA

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model_year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model_year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model_year      1.000000  0.180662
# origin          0.180662  1.000000

# %% [markdown]
# ### USE SEABRON TO VISUALIZE

# %%
fig = plt.figure(figsize=(20,10))
df.plot()
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(20,10))
plt.plot(df['mpg'])
plt.plot(df['cylinders'])
plt.plot(df['origin'])

# %%
font = 14
fig =plt.figure(figsize=(16,8))
axx =fig.add_axes([0, 0, 1, 1])
axx.plot(df['mpg'], '-or')
axx.plot(df['cylinders'], '--b')
axx.plot(df['origin'], '-+g')
axx.legend(['mpg', 'cylinders', 'origin'], fontsize=font)
axx.set_xlabel('Days', fontsize=font)
axx.set_ylabel('Values', fontsize=font)
axx.set_title('Auto Data', fontsize=font)
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.title('Origin PLot')
sns.countplot(x='origin', data=df)
# Out:
# <AxesSubplot:title={'center':'Origin PLot'}, xlabel='origin', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='acceleration', y='mpg', data=df)
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %%
fig = plt.figure(figsize=(30,15))
sns.barplot(x='acceleration', y='mpg', data=df)
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %%
fig = plt.figure(figsize=(20,10))
sns.histplot(x='acceleration', y='mpg', data=df)
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %%
sns.pairplot(df)

# %% [markdown]
# ### DROP CAR NAME

# %%
df.drop('car_name', axis=1)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %% [markdown]
# ### NARROW DATA DOWN TO FEATURES TO FOCUS ON

# %%
df1 = df[['displacement', 'acceleration', 'cylinders']]
df1
# Out:
#      displacement  acceleration  cylinders
# 0           307.0          12.0          8
# 1           350.0          11.5          8
# 2           318.0          11.0          8
# 3           304.0          12.0          8
# 4           302.0          10.5          8
# ..            ...           ...        ...
# 393         140.0          15.6          4
# 394          97.0          24.6          4
# 395         135.0          11.6          4
# 396         120.0          18.6          4
# 397         119.0          19.4          4
#
# [398 rows x 3 columns]

# %% [markdown]
# ### NARROW DOWN FURTHER TO JUST TWO FEATURES

# %%
x = df1.drop('cylinders', axis=1)
y = df1['cylinders']
x.head()
# Out:
#    displacement  acceleration
# 0         307.0          12.0
# 1         350.0          11.5
# 2         318.0          11.0
# 3         304.0          12.0
# 4         302.0          10.5

# %% [markdown]
# ### GET X AND Y AXIS SHAPE

# %%
x.shape, y.shape
# Out:
# ((398, 2), (398,))

# %% [markdown]
# ### TRAIN TEST SPLIT
# ### Use train_test_split to split your data into Training set and Test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((278, 2), (120, 2), (278,), (120,))

# %% [markdown]
# ### BUILDING KNN MODEL INSTANCE WITH N_NEIGHBORS = 2 AND FITTING IT TO THE TRAIN DATA

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# ### CHECK FOR THE ACCURACY OF YOUR MODEL

# %%
from sklearn.metrics import accuracy_score

pred = knn.predict(x_test)
print('Model Accuracy = ', accuracy_score(pred, y_test))
# Out:
# Model Accuracy =  0.9583333333333334

# %% [markdown]
# ### PREDICT AND EVALUATE

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred))
# Out:
# [[69  0  0  0]
#  [ 1  0  1  0]
#  [ 1  0 21  0]
#  [ 0  0  2 25]]

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.97      1.00      0.99        69
#            5       0.00      0.00      0.00         2
#            6       0.88      0.95      0.91        22
#            8       1.00      0.93      0.96        27
#
#     accuracy                           0.96       120
#    macro avg       0.71      0.72      0.72       120
# weighted avg       0.94      0.96      0.95       120
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ### CHOOSING A K VALUE

# %%
error_rate = []
for i in range (1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, y_train)
    pred_i = knn.predict(x_test)
    error_rate.append(np.mean(pred_i != y_test))

# %% [markdown]
# ### CREATING A PLOT USING INFO FROM THE FOR LOOP

# %%
plt.figure(figsize=(16,8))
plt.plot(range(1, 40), error_rate, color='green', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Errot Rate')
# Out:
# Text(0, 0.5, 'Errot Rate')

# %% [markdown]
# ### RETRAIN WITH NEW K VALUE

# %%
knn = KNeighborsClassifier(n_neighbors=30)

knn.fit(x_train, y_train)
pred = knn.predict(x_test)

print('WITH K=30')
print('\n')
print(confusion_matrix(y_test, pred))
print('\n')
print(classification_report(y_test, pred))
# Out:
# WITH K=30
#
#
# [[69  0  0  0]
#  [ 1  0  1  0]
#  [ 2  0 20  0]
#  [ 0  0  2 25]]
#
#
#               precision    recall  f1-score   support
#
#            4       0.96      1.00      0.98        69
#            5       0.00      0.00      0.00         2
#            6       0.87      0.91      0.89        22
#            8       1.00      0.93      0.96        27
#
#     accuracy                           0.95       120
#    macro avg       0.71      0.71      0.71       120
# weighted avg       0.94      0.95      0.94       120
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
